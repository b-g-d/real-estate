# %%
#Importing needed packages

__author__ = 'b'

import ssl
import numpy as np
import math
import matplotlib.pyplot as plt
import pandas as pd
from pandas.tools.plotting import autocorrelation_plot as acf
import statsmodels.api as sm
import googlemaps
import urllib3
import requests
import json

# %%
# Global variables and data
data_file = "../data/real_estate/buncombe_sample.csv"
geocoded_data_file = "../data/real_estate/buncombe_sample_gcode.csv"
server_key = 'AIzaSyCpy_YQJir5GIslpiZ8Lc_c0bWIE3Ajf3Q'
bunc_orig = pd.read_csv(data_file, delimiter=";", header = 0) #, parse_dates = ['day'])
bunc_geoc = pd.read_csv(geocoded_data_file, delimiter=";", header = 0) #, parse_dates = ['day'])

gmaps = googlemaps.Client(key=server_key)
brl = bunc_orig
brl = brl.astype(object)
length = len(brl[[1]])
brl['lat'] = 0
brl['lon'] = 0

# %%
bunc_geoc['ppa'] = bunc_geoc.SellingPrice / bunc_geoc.Acres

# %%
test = bunc_geoc[bunc_geoc.SellingPrice != 0]

# %%
bunc_geoc[bunc_geoc.Class == "CONDOMINIUM"]
# Out:
#       Unnamed: 0  Unnamed: 0.1         ParcelID ActiveStatus    SellDate  \
# 113          113           113  060944646500000            I  2001-09-26
# 177          177           177  060944534300000            I  1996-03-18
# 270          270           270  060944961100000            I  2006-06-19
# 291          291           291  060944646500000            I  2001-09-26
# 312          312           312  060944646500000            I  2001-09-26
# 403          403           403  060944965200000            I  2004-05-11
# 445          445           445  060944447700000            I  2009-10-01
# 526          526           526  060944743600000            I  2002-09-25
# 527          527           527  060944965200000            I  2004-11-16
# 572          572           572  060944753100000            I  2002-04-01
# 594          594           594  0609541159C0016            I  2004-07-07
# 595          595           595  0609541159C0043            I  1999-11-17
# 596          596           596  0609541159C0045            I  2002-03-05
# 602          602           602  0609541159C0019            I  2003-12-09
# 603          603           603  0609541159C0045            I  2002-04-02
# 631          631           631  060944753700000            I  1998-12-01
# 646          646           646  0609541159C0004            I  1997-04-07
# 647          647           647  0609541159C0043            I  2002-09-23
# 648          648           648  060954349100000            I  2001-09-26
# 649          649           649  0609541159C0007            I  2001-09-26
# 650          650           650  0609541159C0010            I  1998-12-01
# 651          651           651  0609541159C0011            I  2012-05-30
# 652          652           652  0609541159C0028            I  2004-03-02
# 659          659           659  060944642600000            I  2008-10-23
# 660          660           660  060944961100000            I  2004-05-11
# 672          672           672  0609541159C0010            I  1998-12-01
# 673          673           673  0609541159C0029            I  2010-01-05
# 674          674           674  0609541159C0039            I  2004-08-27
# 675          675           675  0609541159C0018            I  2012-12-03
# 681          681           681  0609545611C1050            I  2000-01-31
# ...          ...           ...              ...          ...         ...
# 2988        2988          2988  0618591651C0002            A  2009-12-22
# 3428        3428          3428  061917329300000            I  2005-06-24
# 3430        3430          3430  0619179488C0106            A  2003-03-04
# 3447        3447          3447  0619251667C0003            A  1999-05-13
# 3455        3455          3455  061917329900000            I  2005-07-14
# 3465        3465          3465  0619174204C002A            A  2005-07-14
# 3466        3466          3466  0619179488C0114            A  2003-01-22
# 3470        3470          3470  0619179488C0106            A  2008-04-04
# 3475        3475          3475  0619174204C002A            A  2005-07-14
# 3506        3506          3506  061917329300000            I  2005-06-24
# 3509        3509          3509  0619174204C001A            A  2005-06-24
# 3521        3521          3521  061917958100000            I  2004-10-22
# 3528        3528          3528  0619179488C0118            A  2002-09-13
# 3530        3530          3530  0619179488C0108            A  2007-01-23
# 3572        3572          3572  061927057800000            I  2003-03-04
# 3576        3576          3576  0619179488C0118            A  2002-10-14
# 3578        3578          3578  0619251667C0004            A  2000-12-20
# 3583        3583          3583  0619251667C0006            A  1998-02-11
# 3607        3607          3607  061927053500000            I  2007-11-29
# 3615        3615          3615  061927055600000            I  2007-01-23
# 3633        3633          3633  0619179488C0110            A  2003-02-06
# 3669        3669          3669  0619174204C002A            A  2011-07-27
# 3670        3670          3670  0619179488C0116            A  2005-07-07
# 3694        3694          3694  061917958200000            I  2002-10-16
# 3705        3705          3705  0619251667C0001            A  2001-04-26
# 3741        3741          3741  0619179488C0116            A  2010-06-30
# 3786        3786          3786  0619179488C0110            A  2006-07-07
# 3795        3795          3795  061927163100000            I  2003-05-07
# 3939        3939          3939  0619179488C0112            A  2002-05-03
# 3943        3943          3943  0619251667C0006            A  2002-03-25
#
#       SellNum  Seller_Acct                Seller1_Lname Seller1_Fname  \
# 113         3      8160924                       FRICKE      ARTHUR H
# 177         1      8052656                        HICKS      MARTHA B
# 270         1      7955080           HIGHLAND FARMS INC           NaN
# 291         2      8043920           HIGHLAND FARMS INC           NaN
# 312         1      7952231                     GOODLING      ROBERT L
# 403         1      8072778                     CRENSHAW       DOROTHY
# 445         1      8043920           HIGHLAND FARMS INC           NaN
# 526         1      8043920           HIGHLAND FARMS INC           NaN
# 527         1      8043920           HIGHLAND FARMS INC           NaN
# 572         1      7994191                       WALLEY         LEWIS
# 594         1      8043920           HIGHLAND FARMS INC           NaN
# 595         2      8141163                      STIVERS         DAVID
# 596         1      8130844                        LEWIS        JOHN W
# 602         1      8043920           HIGHLAND FARMS INC           NaN
# 603         1      8043920           HIGHLAND FARMS INC           NaN
# 631         2      8043920           HIGHLAND FARMS INC           NaN
# 646         1      8043920           HIGHLAND FARMS INC           NaN
# 647         1      8043920           HIGHLAND FARMS INC           NaN
# 648         1      8043920           HIGHLAND FARMS INC           NaN
# 649         3      8160924                       FRICKE      ARTHUR H
# 650         2      8043920           HIGHLAND FARMS INC           NaN
# 651         2      8043920           HIGHLAND FARMS INC           NaN
# 652         1      8043920           HIGHLAND FARMS INC           NaN
# 659         1      8043920           HIGHLAND FARMS INC           NaN
# 660         2      8043920           HIGHLAND FARMS INC           NaN
# 672         1      8066937         NAHIGAN FAMILY TRUST           NaN
# 673         1      8043920           HIGHLAND FARMS INC           NaN
# 674         1      7994643                        PARKE     KATHRYN E
# 675         1      8043920           HIGHLAND FARMS INC           NaN
# 681         2      8145644            HIGHLAND FARM INC           NaN
# ...       ...          ...                          ...           ...
# 2988        1      8218610                      WITHERS        RUTH F
# 3428        1      8093508                        ALLAN     WILLIAM A
# 3430        1      8093508                        ALLAN     WILLIAM A
# 3447        1      8071391                        PRYOR       ELSIE G
# 3455        2      8172460  BUILT-MORE CONSTRUCTION INC           NaN
# 3465        1      8093508                        ALLAN     WILLIAM A
# 3466        1      8093508                        ALLAN     WILLIAM A
# 3470        1      8176354                  STRINGFIELD     CRYSTAL M
# 3475        2      8172460  BUILT-MORE CONSTRUCTION INC           NaN
# 3506        2      8172460  BUILT-MORE CONSTRUCTION INC           NaN
# 3509        2      8172460  BUILT-MORE CONSTRUCTION INC           NaN
# 3521        1      8172519                        HANKS     CLINTON M
# 3528        1      8093508                        ALLAN     WILLIAM A
# 3530        1      8196447  SALLY B FRAZER LIVING TRUST           NaN
# 3572        1      8093508                        ALLAN     WILLIAM A
# 3576        1      8172519                        HANKS     CLINTON M
# 3578        1      8143254                      BRIDGES      TRUMAN C
# 3583        1      7961619                       FISHER       RUFUS M
# 3607        1      8212527                      SPILKER    PATRICIA G
# 3615        1      8196447  SALLY B FRAZER LIVING TRUST           NaN
# 3633        1      8093508                        ALLAN     WILLIAM A
# 3669        1      8202072                       DANIEL    VIRGINIA P
# 3670        1      8172567                         SELF          JOHN
# 3694        1      8172567                         SELF          JOHN
# 3705        1      8057237                       MILLER       GRACE E
# 3741        1      8212421                       BURKOT        MARY S
# 3786        1      8202494                      WILKENS        JAEMES
# 3795        1      8093508                        ALLAN     WILLIAM A
# 3939        1      8093508                        ALLAN     WILLIAM A
# 3943        1      8121578                    UNDERWOOD     JOHANNA K
#
#      Seller1_Tname    ...        DeedDate DeedInstument Acres        Class  \
# 113      (TRUSTEE)    ...      2001-09-26           WLL     0  CONDOMINIUM
# 177            NaN    ...      1996-03-18           WDT     0  CONDOMINIUM
# 270            NaN    ...      2006-06-19           WDT     0  CONDOMINIUM
# 291            NaN    ...      2001-09-26           WDT     0  CONDOMINIUM
# 312          ET AL    ...      2001-09-26           WDT     0  CONDOMINIUM
# 403            NaN    ...      2004-05-11           WDT     0  CONDOMINIUM
# 445            NaN    ...      2009-10-01           WDT     0  CONDOMINIUM
# 526            NaN    ...      2002-09-25           WDT     0  CONDOMINIUM
# 527            NaN    ...      2004-11-16           WDT     0  CONDOMINIUM
# 572            NaN    ...      2002-04-01           DEE     0  CONDOMINIUM
# 594            NaN    ...      2004-07-07           WDT     0  CONDOMINIUM
# 595            NaN    ...      1999-11-17           WDT     0  CONDOMINIUM
# 596            NaN    ...      2002-03-05           WDT     0  CONDOMINIUM
# 602            NaN    ...      2003-12-09           WDT     0  CONDOMINIUM
# 603            NaN    ...      2002-04-02           WDT     0  CONDOMINIUM
# 631            NaN    ...      1998-12-01           WDT     0  CONDOMINIUM
# 646            NaN    ...      1997-04-07           WDT     0  CONDOMINIUM
# 647            NaN    ...      2002-09-23           WDT     0  CONDOMINIUM
# 648            NaN    ...      2001-09-26           WDT     0  CONDOMINIUM
# 649      (TRUSTEE)    ...      2001-09-26           WLL     0  CONDOMINIUM
# 650            NaN    ...      1998-12-01           WDT     0  CONDOMINIUM
# 651            NaN    ...      2012-05-30           WDT     0  CONDOMINIUM
# 652            NaN    ...      2004-03-02           WDT     0  CONDOMINIUM
# 659            NaN    ...      2008-10-23           WDT     0  CONDOMINIUM
# 660            NaN    ...      2004-05-11           WDT     0  CONDOMINIUM
# 672            NaN    ...      1998-12-01           WDT     0  CONDOMINIUM
# 673            NaN    ...      2010-01-05           WDT     0  CONDOMINIUM
# 674            NaN    ...      2004-08-27           WDT     0  CONDOMINIUM
# 675            NaN    ...      2012-12-03           SWD     0  CONDOMINIUM
# 681            NaN    ...      2000-01-31           WDT     0  CONDOMINIUM
# ...            ...    ...             ...           ...   ...          ...
# 2988           NaN    ...      2009-12-22           WDT     0  CONDOMINIUM
# 3428           NaN    ...      2005-06-24           WDT     0  CONDOMINIUM
# 3430           NaN    ...      2003-03-04           WDT     0  CONDOMINIUM
# 3447           NaN    ...      1999-05-13           ADJ     0  CONDOMINIUM
# 3455           NaN    ...      2005-07-14           WDT     0  CONDOMINIUM
# 3465           NaN    ...      2005-07-14           WDT     0  CONDOMINIUM
# 3466           NaN    ...      2003-01-22           WDT     0  CONDOMINIUM
# 3470           NaN    ...      2008-04-04           WDT     0  CONDOMINIUM
# 3475           NaN    ...      2005-07-14           WDT     0  CONDOMINIUM
# 3506           NaN    ...      2005-06-24           WDT     0  CONDOMINIUM
# 3509           NaN    ...      2005-06-24           WDT     0  CONDOMINIUM
# 3521           NaN    ...      2004-10-22           WDT     0  CONDOMINIUM
# 3528           NaN    ...      2002-09-13           WDT     0  CONDOMINIUM
# 3530           NaN    ...      2007-01-23           WDT     0  CONDOMINIUM
# 3572           NaN    ...      2003-03-04           WDT     0  CONDOMINIUM
# 3576           NaN    ...      2002-10-14           CRD     0  CONDOMINIUM
# 3578          (LE)    ...      2000-12-20           ADJ     0  CONDOMINIUM
# 3583           NaN    ...      1998-02-11           WDT     0  CONDOMINIUM
# 3607           NaN    ...      2007-11-29           WDT     0  CONDOMINIUM
# 3615           NaN    ...      2007-01-23           WDT     0  CONDOMINIUM
# 3633           NaN    ...      2003-02-06           WDT     0  CONDOMINIUM
# 3669           NaN    ...      2011-07-27           SWD     0  CONDOMINIUM
# 3670           NaN    ...      2005-07-07           WDT     0  CONDOMINIUM
# 3694           NaN    ...      2002-10-16           WDT     0  CONDOMINIUM
# 3705           NaN    ...      2001-04-26           ADJ     0  CONDOMINIUM
# 3741           NaN    ...      2010-06-30           WDT     0  CONDOMINIUM
# 3786           NaN    ...      2006-07-07           WDT     0  CONDOMINIUM
# 3795           NaN    ...      2003-05-07           WDT     0  CONDOMINIUM
# 3939           NaN    ...      2002-05-03           WDS     0  CONDOMINIUM
# 3943           NaN    ...      2002-03-25           ADJ     0  CONDOMINIUM
#
#               Neighborhood SellingPrice QualifiedSale VacantLot        lat  \
# 113   HIGHLAND FARMS VILLA            0             N         F  35.611986
# 177   HIGHLAND FARMS VILLA        63000             Y         F  35.612958
# 270   HIGHLAND FARMS VILLA       165000             Y         F  35.612982
# 291   HIGHLAND FARMS VILLA       129000             Y         F  35.612982
# 312   HIGHLAND FARMS VILLA        52500             P         F  35.612982
# 403   HIGHLAND FARMS VILLA        78500             N         F  35.891636
# 445   HIGHLAND FARMS VILLA       210000             Y         F        NaN
# 526   HIGHLAND FARMS VILLA       150000             Y         F        NaN
# 527   HIGHLAND FARMS VILLA       183900             Y         F        NaN
# 572   HIGHLAND FARMS VILLA        55000             N         F        NaN
# 594   HIGHLAND FARMS VILLA       174500             Y         F        NaN
# 595   HIGHLAND FARMS VILLA       145000             Y         F        NaN
# 596   HIGHLAND FARMS VILLA        63000             N         F        NaN
# 602   HIGHLAND FARMS VILLA       110500             Y         F        NaN
# 603   HIGHLAND FARMS VILLA       155000             Y         F        NaN
# 631   HIGHLAND FARMS VILLA        77000             N         F        NaN
# 646   HIGHLAND FARMS VILLA        98000             Y         F        NaN
# 647   HIGHLAND FARMS VILLA       170000             Y         F        NaN
# 648   HIGHLAND FARMS CONDO       180000             P         F        NaN
# 649   HIGHLAND FARMS VILLA            0             N         F        NaN
# 650   HIGHLAND FARMS VILLA        77000             N         F        NaN
# 651   HIGHLAND FARMS VILLA       145000             Y         F        NaN
# 652   HIGHLAND FARMS VILLA       170000             Y         F        NaN
# 659   HIGHLAND FARMS VILLA       215000             Y         F        NaN
# 660   HIGHLAND FARMS VILLA       148580             Y         F        NaN
# 672   HIGHLAND FARMS VILLA        41000             N         F        NaN
# 673   HIGHLAND FARMS VILLA       225000             Y         F        NaN
# 674   HIGHLAND FARMS VILLA        57000             N         F        NaN
# 675   HIGHLAND FARMS VILLA     13509500             N         F        NaN
# 681   HIGHLAND FARMS CONDO       165000             Y         F        NaN
# ...                    ...          ...           ...       ...        ...
# 2988           LLAMA VISTA        51000             Y         F        NaN
# 3428       LAKE VIEW CONDO            0             N         T        NaN
# 3430       PARK LANE CONDO            0             N         F        NaN
# 3447        ORCHARD CONDOS        72000             Y         F        NaN
# 3455       LAKE VIEW CONDO       275000             Y         F        NaN
# 3465       LAKE VIEW CONDO            0             N         T        NaN
# 3466       PARK LANE CONDO            0             N         F        NaN
# 3470       PARK LANE CONDO       198000             Y         F        NaN
# 3475       LAKE VIEW CONDO       275000             Y         F        NaN
# 3506       LAKE VIEW CONDO       199000             N         F        NaN
# 3509       LAKE VIEW CONDO       199000             N         F        NaN
# 3521       PARK LANE CONDO        71000             Y         F        NaN
# 3528       PARK LANE CONDO        60000             N         F        NaN
# 3530       PARK LANE CONDO       170000             Y         F        NaN
# 3572       PARK LANE CONDO            0             N         F        NaN
# 3576       PARK LANE CONDO        60000             N         F        NaN
# 3578        ORCHARD CONDOS        90000             Y         F        NaN
# 3583        ORCHARD CONDOS        89000             P         F        NaN
# 3607       PARK LANE CONDO       191000             Y         F        NaN
# 3615       PARK LANE CONDO       170000             Y         F        NaN
# 3633       PARK LANE CONDO       135000             Y         F        NaN
# 3669       LAKE VIEW CONDO            0             N         F        NaN
# 3670       PARK LANE CONDO        72500             Y         F        NaN
# 3694       PARK LANE CONDO        60000             N         F        NaN
# 3705        ORCHARD CONDOS        95000             Y         F        NaN
# 3741       PARK LANE CONDO        96500             Y         F        NaN
# 3786       PARK LANE CONDO       165000             Y         F        NaN
# 3795       PARK LANE CONDO       137000             Y         F        NaN
# 3939       PARK LANE CONDO       141000             Y         F        NaN
# 3943        ORCHARD CONDOS       102000             Y         F        NaN
#
#             lon
# 113  -82.349417
# 177  -82.346738
# 270  -82.350726
# 291  -82.350726
# 312  -82.350726
# 403  -78.659757
# 445         NaN
# 526         NaN
# 527         NaN
# 572         NaN
# 594         NaN
# 595         NaN
# 596         NaN
# 602         NaN
# 603         NaN
# 631         NaN
# 646         NaN
# 647         NaN
# 648         NaN
# 649         NaN
# 650         NaN
# 651         NaN
# 652         NaN
# 659         NaN
# 660         NaN
# 672         NaN
# 673         NaN
# 674         NaN
# 675         NaN
# 681         NaN
# ...         ...
# 2988        NaN
# 3428        NaN
# 3430        NaN
# 3447        NaN
# 3455        NaN
# 3465        NaN
# 3466        NaN
# 3470        NaN
# 3475        NaN
# 3506        NaN
# 3509        NaN
# 3521        NaN
# 3528        NaN
# 3530        NaN
# 3572        NaN
# 3576        NaN
# 3578        NaN
# 3583        NaN
# 3607        NaN
# 3615        NaN
# 3633        NaN
# 3669        NaN
# 3670        NaN
# 3694        NaN
# 3705        NaN
# 3741        NaN
# 3786        NaN
# 3795        NaN
# 3939        NaN
# 3943        NaN
#
# [440 rows x 61 columns]

# %%
#Finding the first address that hasn't been geocoded
def find_first_blank():
    first_blank = 0 #find the first blank latitude field in the geocoded data 
    while (math.isnan(bunc_geoc.loc[first_blank,'lat']) == False):
        first_blank +=1
    return first_blank

# %%
min_lat, min_lon = 35.2361068725586, -82.8805084228516
max_lat, max_lon = 35.9641075134277, -82.1525115966797
bunc_centroid = str(min_lat) + "," + str(min_lon) + "|" + str(max_lat) + "," + str(max_lon)

bunc_centroid
# Out:
# '35.2361068725586,-82.8805084228516|35.9641075134277,-82.1525115966797'

# %%
count = 0
daily_max = 2450
url = 'https://maps.googleapis.com/maps/api/geocode/json'
acceptable_types = ['RANGE_INTERPOLATED', 'ROOFTOP', 'GEOMETRIC_CENTER']
acceptable_location_types =['bus_station', 'transit_station', 'establishment','intersection','street_number','parking','establishment']


# details for buncombe 
min_lat, min_lon = 35.2361068725586, -82.8805084228516
max_lat, max_lon = 35.9641075134277, -82.1525115966797
bunc_centroid = str(min_lat) + "," + str(min_lon) + "|" + str(max_lat) + "," + str(max_lon)


def make_geometry_tuple(geometry):
    location_type = geometry['location_type']
    lat = geometry['location']['lat']
    lon = geometry['location']['lng']
    return (lat,lon,location_type)


def geocode(address):
    global count
    global daily_max
    
    county = "Buncombe"
    address = address

    if address.find('NC') == -1:
        address = address + ' ' + county + ', NC'
    #address = title_case(address, county)
    payload = {'address':address, 'bounds': bunc_centroid}

    ### Call to Google
    page = requests.get(url,params=payload)
    try:
       results = json.loads(page.text)
    except ValueError:
        time.sleep(120)
        requests.get(url, params=payload)
        results = json.loads(page.text)

    if results['status'] == 'OVER_QUERY_LIMIT':
        time.sleep(120)
        page = requests.get(url,params=payload)
        results = json.loads(page.text)
    if results['status'] != 'OK':
        return False
    ###
    
    ### Post-call processing
    data = results['results'][0]
    geometry = data['geometry']
    address_components = data['address_components']
    formatted_address = data['formatted_address']
    found_types = list(set(acceptable_location_types) & set(data['types']))
    if geometry['location_type'] in acceptable_types or len(found_types):
        geometry_tuple = make_geometry_tuple(geometry)
        update = (geometry_tuple[0], geometry_tuple[1])
        return update
    else:
        return (-1, -1)
    ###
    
    
    ### Iterating up
    count += 1
    if count == daily_max:
        exit()
    time.sleep(0.25)

# %%
#Run over only uncoded addresses
addresses = bunc_orig['Seller_Address2'] + ", " + brl['Seller_City'] + ", " + brl['Seller_State'] + " " + brl['Seller_Zip1'].astype(str)
i = find_first_blank()

length = i + 2


while i < length:
    address = addresses[i]
    lat_lon = geocode(address)
    bunc_geoc.loc[i,'lat'], bunc_geoc.loc[i,'lon'] = lat_lon[0], lat_lon[1]
    i = i + 1
# Out:
# this is working
# 35.08509
# this is working
# 35.586051

# %%
#Resaving updated file
bunc_geoc.to_csv(gecoded_data, sep = ";")

# %%
bre = bunc_geoc
bre.loc[:,'acre_price'] = bre.SellingPrice / bre.Acres

# %%
#bre = bre[(bre.acre_price != 0) & (math.isnan(bre.acre_price) == False)]

bre = bre.loc[:,(math.isnan(bre.acre_price) == False)]

#plt.hist(lots.Acres, 50, normed=1, histtype='stepfilled')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-60-c7a319f387ab> in <module>()
#       1 #bre = bre[(bre.acre_price != 0) & (math.isnan(bre.acre_price) == False)]
#       2
# ----> 3 bre = bre.loc[:,(math.isnan(bre.acre_price) == False)]
#       4
#       5 #plt.hist(lots.Acres, 50, normed=1, histtype='stepfilled')
#
# /Library/Frameworks/Python.framework/Versions/3.4/lib/python3.4/site-packages/pandas/core/series.py in wrapper(self)
#      74             return converter(self.iloc[0])
#      75         raise TypeError(
# ---> 76             "cannot convert the series to {0}".format(str(converter)))
#      77     return wrapper
#      78
#
# TypeError: cannot convert the series to <class 'float'>

# %%
bunc_geoc_no_zeros.columns.values
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-05fafc5e735c> in <module>()
# ----> 1 bunc_geoc_no_zeros.columns.values
#
# NameError: name 'bunc_geoc_no_zeros' is not defined

# %%
#Plottting
limit = find_first_blank()
bunc_geoc_no_zeros = bunc_geoc[bunc_geoc.lat != 0]
plot_data = [bunc_geoc_no_zeros['lon'][0:limit],bunc_geoc_no_zeros['lat'][0:limit]]
plt.plot(plot_data[0],plot_data[1], 'ro')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-37f85ea61ce4> in <module>()
#       1 #Plottting
# ----> 2 limit = find_first_blank()
#       3 bunc_geoc_no_zeros = bunc_geoc[bunc_geoc.lat != 0]
#       4 plot_data = [bunc_geoc_no_zeros['lon'][0:limit],bunc_geoc_no_zeros['lat'][0:limit]]
#       5 plt.plot(plot_data[0],plot_data[1], 'ro')
#
# NameError: name 'find_first_blank' is not defined

# %%
## create map of purchases that plots them over time - 

## create moving average of price per acre 

## crea
